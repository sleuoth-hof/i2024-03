# %%
import finnhub
import json
from datetime import datetime
import csv
import pandas as pd
import os

# %%
def getfinnhubnews(api_key):
    try:
        finnhub_client = finnhub.Client(api_key=api_key)
        news = list(finnhub_client.general_news('general', min_id=0))
        print(news)
        return news
    except Exception as e:
        print("Fehler beim Abrufen der Nachrichten:", e)
        return []

def convertTimestamp(timestamp):
    return datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')

def writeNewsToCsv(news, csv_file):
    csv_header = ['category', 'datetime', 'headline', 'id', 'image', 'related', 'source', 'summary', 'url']
    try:
        with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=csv_header)
            writer.writeheader()
            for entry in news:
                entry['datetime'] = convertTimestamp(entry['datetime'])
                writer.writerow(entry)
        print("Message write in cnv", csv_file)
    except Exception as e:
        print("ERROR", e)


api_key = "cokf2gpr01qq4pkujt6gcokf2gpr01qq4pkujt70"
news = getfinnhubnews(api_key)
if news:
    writeNewsToCsv(news, 'finnhubNews.csv')
# Out:
# [{'category': 'top news', 'datetime': 1714502156, 'headline': "How to save for retirement if your company doesn't offer a 401(k)", 'id': 7362549, 'image': 'https://image.cnbcfm.com/api/v1/image/107408193-1714488397929-GettyImages-2133181950.jpg?v=1714488466&w=1920&h=1080', 'related': '', 'source': 'CNBC', 'summary': 'Not every employer offers a 401(k) retirement account, but there are suitable alternatives.', 'url': 'https://www.cnbc.com/2024/04/30/how-to-save-for-retirement-if-your-company-doesnt-offer-a-401k.html'}, {'category': 'top news', 'datetime': 1714501980, 'headline': 'Why natural-gas prices look set to post their first monthly gain since October', 'id': 7362548, 'image': '', 'related': '', 'source': 'MarketWatch', 'summary': 'Natural-gas futures have been among the largest commodity gainers in April — on track to post a monthly rise of around 15% as traders bet on a slowdown in U.S. production ahead of the high-demand summer cooling season.', 'url': 'https://www.marketwatch.com/story/why-natural-gas-prices-look-set-to-post-their-first-monthly-gain-since-october-0d2002d8'}, {'category': 'top news', 'datetime': 1714500960, 'headline': 'This is the big question markets have for Fed’s Jerome Powell, BlackRock says', 'id': 7362547, 'image': '', 'related': '', 'source': 'MarketWatch', 'summary': 'The market will be listening closely on Wednesday for messaging from Federal Reserve Chairman Jerome Powell about whether interest-rate hikes may be on the table due to inflation worries.', 'url': 'https://www.marketwatch.com/story/this-is-the-big-question-markets-have-for-feds-jerome-powell-blackrock-says-5b9d1d73'}, {'category': 'top news', 'datetime': 1714499400, 'headline': 'Cannabis stocks rally after AP reports DEA will propose reclassifying drug as Schedule III', 'id': 7362536, 'image': '', 'related': '', 'source': 'MarketWatch', 'summary': 'AdvisorShares Pure U.S. Cannabis ETF jumps 28%.', 'url': 'https://www.marketwatch.com/story/cannabis-stocks-rally-as-ap-reports-imminent-rescheduling-proposal-by-dea-f1896fd3'}, {'category': 'top news', 'datetime': 1714499040, 'headline': 'The ‘Magnificent Seven’ aren’t seven. Or magnificent.', 'id': 7362537, 'image': '', 'related': '', 'source': 'MarketWatch', 'summary': 'Time and again investors discover a small group of stocks or investments that supposedly can’t fail.', 'url': 'https://www.marketwatch.com/story/the-magnificent-seven-arent-seven-or-magnificent-83e9ea11'}, {'category': 'top news', 'datetime': 1714499040, 'headline': 'Bitcoin is on pace for its worst month since November 2022. Here’s what’s driving the decline.', 'id': 7362538, 'image': '', 'related': '', 'source': 'MarketWatch', 'summary': 'Bitcoin is on pace for its worst month in nearly a year and a half — despite the cryptocurrency’s so-called halving event on April 19, which some crypto bulls had hoped would provide a fresh catalyst for a rally.', 'url': 'https://www.marketwatch.com/story/bitcoin-is-on-pace-for-its-worst-month-since-november-2022-heres-whats-driving-the-decline-e168ddad'}, {'category': 'top news', 'datetime': 1714497420, 'headline': 'Joe Biden proposes hitting Donald Trump with a $1 billion tax bill', 'id': 7362529, 'image': '', 'related': '', 'source': 'MarketWatch', 'summary': 'The president has proposed a tax on unrealized capital gains for people worth more than $100 million. Who do we know who falls into that category?', 'url': 'https://www.marketwatch.com/story/joe-biden-proposes-hitting-donald-trump-with-a-1-billion-tax-bill-e9789774'}, {'category': 'top news', 'datetime': 1714495764, 'headline': 'Over $1 billion in unclaimed tax refunds is set to expire in just over 2 weeks, IRS says—here’s how to claim yours', 'id': 7362524, 'image': 'https://image.cnbcfm.com/api/v1/image/107408271-1714492966643-gettyimages-1170711782-_mg_3007-edit.jpeg?v=1714492975&w=1920&h=1080', 'related': '', 'source': 'CNBC', 'summary': "The IRS says it's holding onto over $1 billion in unclaimed tax refunds. Filers ...
# Message write in cnv finnhubNews.csv

# %%
df = pd.read_csv('finnhubNews.csv')
print(df.head(5))
# Out:
#    category             datetime  \
# 0  top news  2024-04-29 11:05:00
# 1  top news  2024-04-29 11:04:00
# 2  top news  2024-04-29 11:03:00
# 3  top news  2024-04-29 11:01:00
# 4  top news  2024-04-29 10:55:00
#
#                                             headline       id image  related  \
# 0  Cheaper, better, safer, healthier and more fun...  7361921   NaN      NaN
# 1  Mercedes-Benz is making a radical change to th...  7361922   NaN      NaN
# 2  These are the 10 cheapest car brands to mainta...  7361923   NaN      NaN
# 3  Photographer Annie Leibovitz lists her 65-acre...  7361924   NaN      NaN
# 4  Philips shares soar 30% after U.S. litigation ...  7361920   NaN      NaN
#
#         source                                            summary  \
# 0  MarketWatch  What makes a city a great place to live? The m...
# 1  MarketWatch  The electric G has shocking horsepower and an ...
# 2  MarketWatch  Tesla tops this list of the least expensive au...
# 3  MarketWatch  Legendary photographer Annie Leibovitz, famous...
# 4  MarketWatch  The company said it would pay $1.1 billion to ...
#
#                                                  url
# 0  https://www.marketwatch.com/story/cheaper-bett...
# 1  https://www.marketwatch.com/story/mercedes-ben...
# 2  https://www.marketwatch.com/story/these-are-th...
# 3  https://www.marketwatch.com/story/photographer...
# 4  https://www.marketwatch.com/story/philips-shar...

# %%
# Out:
# E
# ======================================================================
# ERROR: C:\Users\Manuel\AppData\Roaming\jupyter\runtime\kernel-c362a24e-a6f7-41ef-ad87-cae55a6c108a (unittest.loader._FailedTest.C:\Users\Manuel\AppData\Roaming\jupyter\runtime\kernel-c362a24e-a6f7-41ef-ad87-cae55a6c108a)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\Manuel\AppData\Roaming\jupyter\runtime\kernel-c362a24e-a6f7-41ef-ad87-cae55a6c108a'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# C:\Users\Manuel\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
