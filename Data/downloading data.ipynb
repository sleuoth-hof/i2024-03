# %%
import yfinance as yf
import pandas as pd


ticker_data = pd.read_csv('symbols.csv')


for index, row in ticker_data.iterrows():
    ticker = row['Name']  
    try:
        data = yf.download(ticker)
        if not data.empty:
            data.to_csv(f'{ticker}_historical_data.csv')
            print(f"Downloaded historical data for {ticker}")
        else:
            print(f"No data available for {ticker}")
    except Exception as e:
        print(f"Error downloading data for {ticker}: {str(e)}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for UVXY
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for BBJP
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for CBOE
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for IDV
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for BBEU
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for IEFA
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for VXX
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for GOVT
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
list = ["BTC", "ETH", "USDT", "BNB", "SOL", "USDC", "XRP", "TON", "DOGE", "ADA", "SHIB", "AVAX", "TRX", "DOT", "BCH", "LINK", "NEAR", "MATIC", "LTC", "ICP", "LEO", "DAI", "RNDR", "UNI", "ETC", "HBAR", "FDUSD", "APT", "PEPE", "IMX", "ATOM", "CRO", "MNT", "FIL", "WIF", "XLM", "OKB", "KAS", "STX", "GRT", "ARB", "OP", "AR", "TAO", "VET", "MKR", "XMR", "SUI", "INJ", "FTM", "THETA", "RUNE", "FET", "TIA", "FLOKI", "LDO", "BGB", "BONK", "ALGO", "JUP", "SEI", "CORE", "AKT", "GALA", "ENA", "FLOW", "AAVE", "WLD", "BSV", "AGIX", "BEAM", "QNT", "DYDX", "BTT", "ONDO", "CHZ", "FLR", "W", "NEO", "EGLD", "PENDLE", "AXS", "KCS", "SAND", "XEC", "STRK", "XTZ", "JASMY", "MINA", "AIOZ", "EOS", "CKB", "USDD", "PYTH", "KAVA", "CAKE", "NEXO", "IOTA", "AXL", "TFUEL", "LUNC", "RBN", "KLAY", "BTG", "BLUR", "ROSE", "XAUt", "LPT", "OM", "SATS", "WEMIX", "GLM", "OSMO", "PRIME", "FTT", "OCEAN", "ARKM", "WOO"
]

# %%
len(list)
# Out:
# 118

# %%
import yfinance as yf
import pandas as pd

# Read ticker symbols from a list
ticker_names = [
    "BTC", "ETH", "USDT", "BNB", "SOL", "USDC", "XRP", "TON", "DOGE", "ADA", "SHIB", "AVAX", "TRX", "DOT", "BCH", "LINK", "NEAR", "MATIC", "LTC", "ICP", "LEO", "DAI", "RNDR", "UNI", "ETC", "HBAR", "FDUSD", "APT", "PEPE", "IMX", "ATOM", "CRO", "MNT", "FIL", "WIF", "XLM", "OKB", "KAS", "STX", "GRT", "ARB", "OP", "AR", "TAO", "VET", "MKR", "XMR", "SUI", "INJ", "FTM", "THETA", "RUNE", "FET", "TIA", "FLOKI", "LDO", "BGB", "BONK", "ALGO", "JUP", "SEI", "CORE", "AKT", "GALA", "ENA", "FLOW", "AAVE", "WLD", "BSV", "AGIX", "BEAM", "QNT", "DYDX", "BTT", "ONDO", "CHZ", "FLR", "W", "NEO", "EGLD", "PENDLE", "AXS", "KCS", "SAND", "XEC", "STRK", "XTZ", "JASMY", "MINA", "AIOZ", "EOS", "CKB", "USDD", "PYTH", "KAVA", "CAKE", "NEXO", "IOTA", "AXL", "TFUEL", "LUNC", "RBN", "KLAY", "BTG", "BLUR", "ROSE", "XAUt", "LPT", "OM", "SATS", "WEMIX", "GLM", "OSMO", "PRIME", "FTT", "OCEAN", "ARKM", "WOO"
]

for ticker in ticker_names:
    try:
        data = yf.download(ticker)
        if not data.empty:
            data.to_csv(f'{ticker}_historical_data.csv')
            print(f"Downloaded historical data for {ticker}")
        else:
            print(f"No data available for {ticker}")
    except Exception as e:
        print(f"Error downloading data for {ticker}: {str(e)}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for BTC
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ETH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# No data available for ETH
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['USDT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# No data available for USDT
# Downloaded historical data for BNB
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for SOL
# Downloaded historical data for USDC
# [*********************100%%**********************]  1 of 1 completed
# Downloaded historical data for XRP
# ...

# %%
import yfinance as yf
import pandas as pd


ticker_data = pd.read_excel('Euronext_Equities_2024-05-11.xlsx')


for index, row in ticker_data.iterrows():
    ticker = row['Symbol']  
    try:
        data = yf.download(ticker)
        if not data.empty:
            data.to_csv(f'{ticker}_historical_data.csv')
            print(f"Downloaded historical data for {ticker}")
        else:
            print(f"No data available for {ticker}")
    except Exception as e:
        print(f"Error downloading data for {ticker}: {str(e)}")
# Out:
# Error downloading data for nan: 'float' object has no attribute 'replace'
# Error downloading data for nan: 'float' object has no attribute 'replace'
# Error downloading data for nan: 'float' object has no attribute 'replace'
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALMIL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# No data available for ALMIL
# Error downloading data for 2020: 'int' object has no attribute 'replace'
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AL2SI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# No data available for AL2SI
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['4DDD']: Exception('%ticker%: No timezone found, symbol may be delisted')
# No data available for 4DDD
# [*********************100%%**********************]  1 of 1 completed
#
# ...
