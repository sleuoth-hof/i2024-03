# %%
import seaborn as sb
import pandas as pd

# %%
data=pd.read_csv("BTC-USD_table_all_time.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 3514  2024-05-01  60609.496094  60780.500000  56555.292969  58254.011719
# 3515  2024-05-02  58253.703125  59602.296875  56937.203125  59123.433594
# 3516  2024-05-03  59122.300781  63320.503906  58848.312500  62889.835938
# 3517  2024-05-04  62891.031250  64494.957031  62599.351562  63891.472656
# 3518  2024-05-05  63899.585938  64035.136719  63035.859375  63855.265625
#
#          Adj Close       Volume
# ...

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
data.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
sb.set_theme(style="whitegrid")
btc = sb.lineplot(x="Date",y="Open", data=data)

# %%
sb.set_theme(style="whitegrid")
btc = sb.lineplot(x="Date",y="Open", data=data)
